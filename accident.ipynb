# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

# %%
df = pd. read_csv("driverresponse.csv")
df. info
df. head()
# Out:
#    index  sno            stateut     region  regionid  alcintake2014  \
# 0      0    1     Andhra Pradesh      south         2            594
# 1      1    2  Arunachal Pradesh  northeast         5             11
# 2      2    3              Assam  northeast         5            613
# 3      3    4              Bihar      north         1           1680
# 4      4    5       Chhattisgarh     centre         9            335
#
#    overspeed2014  overtaking2014  lanejumping2014  wrongside2014  ...  \
# 0        12747.0             507              328            668  ...
# 1           16.0               0                0              0  ...
# 2         4596.0             129              104            156  ...
# 3         1496.0             278              236            308  ...
# 4         6720.0             188              313            266  ...
#
#    asleep2014  othercause2014  alcintake2016  overspeed2016  signalavoid2016  \
# ...

# %%
df = df. iloc[:,2:]
df. head()
# Out:
#              stateut     region  regionid  alcintake2014  overspeed2014  \
# 0     Andhra Pradesh      south         2            594        12747.0
# 1  Arunachal Pradesh  northeast         5             11           16.0
# 2              Assam  northeast         5            613         4596.0
# 3              Bihar      north         1           1680         1496.0
# 4       Chhattisgarh     centre         9            335         6720.0
#
#    overtaking2014  lanejumping2014  wrongside2014  signalavoid2014  \
# 0             507              328            668               29
# 1               0                0              0                0
# 2             129              104            156                7
# 3             278              236            308                7
# 4             188              313            266               10
#
#    asleep2014  othercause2014  alcintake2016  overspeed2016  signalavoid2016  \
# ...

# %%
#Data Visualization
for column in df.columns:
    plt.hist(df[column])
    plt.title(column)
    plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
sns.pairplot(df.iloc[:, :])

# %%
df = df. drop(["regionid"], axis = 1)
df. head()
# Out:
#              stateut     region  alcintake2014  overspeed2014  overtaking2014  \
# 0     Andhra Pradesh      south            594        12747.0             507
# 1  Arunachal Pradesh  northeast             11           16.0               0
# 2              Assam  northeast            613         4596.0             129
# 3              Bihar      north           1680         1496.0             278
# 4       Chhattisgarh     centre            335         6720.0             188
#
#    lanejumping2014  wrongside2014  signalavoid2014  asleep2014  \
# 0              328            668               29         154
# 1                0              0                0           0
# 2              104            156                7           3
# 3              236            308                7          72
# 4              313            266               10          81
#
#    othercause2014  alcintake2016  overspeed2016  signalavoid2016  \
# ...

# %%
df['Total'] = df. sum(axis = 1)
df. head()
# Out:
# C:\Users\debna\AppData\Local\Temp\ipykernel_17156\1122926746.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Total'] = df. sum(axis = 1)
#              stateut     region  alcintake2014  overspeed2014  overtaking2014  \
# 0     Andhra Pradesh      south            594        12747.0             507
# 1  Arunachal Pradesh  northeast             11           16.0               0
# 2              Assam  northeast            613         4596.0             129
# 3              Bihar      north           1680         1496.0             278
# 4       Chhattisgarh     centre            335         6720.0             188
#
#    lanejumping2014  wrongside2014  signalavoid2014  asleep2014  \
# 0              328            668               29         154
# ...

# %%
#Scatterplot
plt. scatter(x = df["overspeed2014"], y = df["Total"], color = 'green')

# %%
#Scatterplot
plt. scatter(x = df["alcintake2014"], y = df["Total"], color = 'green')

# %%
df_region = df. groupby('region', axis=0).sum()
print(type(df. groupby('region', axis=0)))
df_region. head()
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
#            alcintake2014  overspeed2014  overtaking2014  lanejumping2014  \
# region
# centre              6091        39279.0            2283             2506
# east                  28         3886.0             281              186
# north               5481        16371.0            1122             1121
# northeast            748         4731.0             129              104
# northwest            915        11395.0             102             1157
#
#            wrongside2014  signalavoid2014  asleep2014  othercause2014  \
# region
# centre              2508              234         491            9066
# east                 235              107          49            1384
# north               1808              239         498            3193
# northeast            182                7           3             771
# northwest            656                2         176            1803
#
# ...

# %%
df_region['Total'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,    
                            )

plt.title('Total accident in region')
plt.axis('equal')
plt.show()
